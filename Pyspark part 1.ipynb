# %%
# !pip install pyspark
# Out:
# ...
# [notice] A new release of pip is available: 24.1.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      ---------------------------------------- 0.1/317.3 MB 1.3 MB/s eta 0:04:01
#      ---------------------------------------- 0.2/317.3 MB 1.1 MB/s eta 0:04:50
#      ---------------------------------------- 0.2/317.3 MB 1.0 MB/s eta 0:05:05
#      ---------------------------------------- 0.3/317.3 MB 1.1 MB/s eta 0:04:39
#      ---------------------------------------- 0.3/317.3 MB 1.2 MB/s eta 0:04:17
#      ---------------------------------------- 0.4/317.3 MB 1.3 MB/s eta 0:04:08
#      ---------------------------------------- 0.5/317.3 MB 1.3 MB/s eta 0:03:57
#      ---------------------------------------- 0.6/317.3 MB 1.3 MB/s eta 0:03:58
# ...

# %%
import pyspark

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\\Users\\prana\\Documents\\Python data\\Book12.csv')
data
# Out:
#    S.No.       Name  Age
# 0      1      Krish   31
# 1      2  Sudhanshu   30
# 2      3      Sunny   29

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://PRANAY:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data_pyspark = spark.read.csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv')

# %%
data_pyspark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string]

# %%
data_pyspark.show()
# Out:
# +-----+---------+---+
# |  _c0|      _c1|_c2|
# +-----+---------+---+
# |S.No.|     Name|Age|
# |    1|    Krish| 31|
# |    2|Sudhanshu| 30|
# |    3|    Sunny| 29|
# +-----+---------+---+

# %%
data_pyspark = spark.read.option('header','true').csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv')

# %%
type(data_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
data_pyspark.head(3)
# Out:
# [Row(S.No.=1, Name='Krish', Age=31, Experience=10),
#  Row(S.No.=2, Name='Sudhanshu', Age=30, Experience=8),
#  Row(S.No.=3, Name='Sunny', Age=29, Experience=4)]

# %%
data_pyspark.printSchema()
# Out:
# root
#  |-- S.No.: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
