# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('DataFrame').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://PRANAY:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>DataFrame</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.read.option('header','true').csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv')
# Out:
# DataFrame[Name: string, Age: string, Experience: string]

# %%
df_pyspark = spark.read.option('header','true').csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv')

# %%
df_pyspark = spark.read.option('header','true').csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv',inferSchema=True)

# %%
# Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('C:\\Users\\prana\\Documents\\Python data\\Book12.csv',header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# |     Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', 'Age', 'Experience']

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', Age=31, Experience=10),
#  Row(Name='Sudhanshu', Age=30, Experience=8),
#  Row(Name='Sunny', Age=29, Experience=4)]

# %%
df_pyspark.select('Name')
# Out:
# DataFrame[Name: string]

# %%
df_pyspark.select('Name').show()
# Out:
# +---------+
# |     Name|
# +---------+
# |    Krish|
# |Sudhanshu|
# |    Sunny|
# +---------+

# %%
type(df_pyspark.select('Name'))
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.select(['Name', 'Experience'])
# Out:
# DataFrame[Name: string, Experience: int]

# %%
df_pyspark.select(['Name', 'Experience']).show()
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |    Krish|        10|
# |Sudhanshu|         8|
# |    Sunny|         4|
# +---------+----------+

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience', 'int')]

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string, Name: string, Age: string, Experience: string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+-----+----+-----------------+
# |summary| Name| Age|       Experience|
# +-------+-----+----+-----------------+
# |  count|    3|   3|                3|
# |   mean| NULL|30.0|7.333333333333333|
# | stddev| NULL| 1.0|3.055050463303893|
# |    min|Krish|  29|                4|
# |    max|Sunny|  31|               10|
# +-------+-----+----+-----------------+

# %%
# Adding columns in data frame
df_pyspark.withColumn('Experience after 2 years',df_pyspark['Experience']+2)
# Out:
# DataFrame[Name: string, Age: int, Experience: int, Experience after 2 years: int]

# %%
df_pyspark = df_pyspark.withColumn('Experience after 2 years',df_pyspark['Experience']+2)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------------------------+
# |     Name|Age|Experience|Experience after 2 years|
# +---------+---+----------+------------------------+
# |    Krish| 31|        10|                      12|
# |Sudhanshu| 30|         8|                      10|
# |    Sunny| 29|         4|                       6|
# +---------+---+----------+------------------------+

# %%
#drop the column
df_pyspark = df_pyspark.drop('Experience after 2 years')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# |     Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
#Rename the columns
df_pyspark = df_pyspark.withColumnRenamed('Name','New Name')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# | New Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+
